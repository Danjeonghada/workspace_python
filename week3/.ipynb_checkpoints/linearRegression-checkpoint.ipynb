# %% [markdown]
# ## 1. 선형 회귀 : 예측하고 수정하기 (먼저 선 긋고 수정하기)
# - 선형회귀는 연속된 값을 예측할 때 사용하며 (데이터에 따라 선형, 비선형, 다항) 회귀가 있음.

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
# 공부시간 x, 성적 y
x = np.array([2, 4, 6, 8])
y = np.array([81, 93, 91, 97])
plt.scatter(x, y)

# %%
# 임의의 기울기 :a와, y절편:b 값을 초기화
a = 0
b = 0
# 학습률
lr = 0.01
# 몇번 학습할지
epochs = 2001
# x 수량
n = len(x)

# %%
# optimizer (경사하강법)
for i in range(epochs):
    y_pred = a * x + b # 예측값을 구하는 식
    error = y - y_pred # 정답(실제값)과 예측값의 차이를 구함.

    a_diff = (2 / n) * sum(-x * (error)) # 오차 함수를 a로 편미분한 값.
    b_diff = (2 / n) * sum(-(error))     # 오차 함수를 b로 편미분한 값.

    a = a - lr * a_diff # 학습률을 곱해 기존의 a값을 업데이트
    b = b - lr * b_diff # ..
    if i % 100 == 0:
        print("epoch=%.f, 기울기=%.04f, 절편=%.04f" %(i, a, b))
# Out:
# epoch=0, 기울기=9.2800, 절편=1.8100
# epoch=100, 기울기=11.5301, 절편=23.9186
# epoch=200, 기울기=8.9703, 절편=39.1944
# epoch=300, 기울기=7.1204, 절편=50.2337
# epoch=400, 기울기=5.7836, 절편=58.2115
# epoch=500, 기울기=4.8175, 절편=63.9768
# epoch=600, 기울기=4.1193, 절편=68.1432
# epoch=700, 기울기=3.6148, 절편=71.1541
# epoch=800, 기울기=3.2501, 절편=73.3300
# epoch=900, 기울기=2.9866, 절편=74.9025
# epoch=1000, 기울기=2.7962, 절편=76.0388
# epoch=1100, 기울기=2.6586, 절편=76.8601
# epoch=1200, 기울기=2.5591, 절편=77.4535
# epoch=1300, 기울기=2.4873, 절편=77.8824
# epoch=1400, 기울기=2.4353, 절편=78.1924
# epoch=1500, 기울기=2.3978, 절편=78.4163
# epoch=1600, 기울기=2.3707, 절편=78.5782
# epoch=1700, 기울기=2.3511, 절편=78.6952
# epoch=1800, 기울기=2.3369, 절편=78.7797
# epoch=1900, 기울기=2.3267, 절편=78.8408
# epoch=2000, 기울기=2.3193, 절편=78.8850

# %%
# 최종 a, b를 대입하여 그래프를 출력
y_pred = a * x + b
plt.scatter(x, y)
plt.plot(x, y_pred, 'r')

# %%
# 공부시간 x1, 과외시간 x2, 성적 y
x1 = np.array([2, 4, 6, 8])
x2 = np.array([0, 4, 2, 3])
y = np.array([81, 93, 91, 97])
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.scatter3D(x1, x2, y)

# %%
a1 = 0
a2 = 0
b = 0
lr = 0.001
epoch = 2001
n = len(x1)

# %%
for i in range(epochs):
    y_pred = a1 * x1 + a2 * x2 + b
    error = y - y_pred
    a1_diff = (2/n) * sum(-x1 * (error))
    a2_diff = (2/n) * sum(-x2 * (error))
    b_diff = (2/n) * sum(-(error))

    a1 = a1 - lr * a1_diff
    a2 = a2 - lr * a2_diff
    b = b - lr * b_diff
    if i % 100 == 0:
        print("epoch=%.f, 기울기=%.04f, 기울기2=%.04f 절편=%.04f" %(i, a1, a2, b))
# Out:
# epoch=0, 기울기=nan, 기울기2=nan 절편=nan
# epoch=100, 기울기=nan, 기울기2=nan 절편=nan
# epoch=200, 기울기=nan, 기울기2=nan 절편=nan
# epoch=300, 기울기=nan, 기울기2=nan 절편=nan
# epoch=400, 기울기=nan, 기울기2=nan 절편=nan
# epoch=500, 기울기=nan, 기울기2=nan 절편=nan
# epoch=600, 기울기=nan, 기울기2=nan 절편=nan
# epoch=700, 기울기=nan, 기울기2=nan 절편=nan
# epoch=800, 기울기=nan, 기울기2=nan 절편=nan
# epoch=900, 기울기=nan, 기울기2=nan 절편=nan
# epoch=1000, 기울기=nan, 기울기2=nan 절편=nan
# epoch=1100, 기울기=nan, 기울기2=nan 절편=nan
# epoch=1200, 기울기=nan, 기울기2=nan 절편=nan
# epoch=1300, 기울기=nan, 기울기2=nan 절편=nan
# epoch=1400, 기울기=nan, 기울기2=nan 절편=nan
# epoch=1500, 기울기=nan, 기울기2=nan 절편=nan
# epoch=1600, 기울기=nan, 기울기2=nan 절편=nan
# epoch=1700, 기울기=nan, 기울기2=nan 절편=nan
# epoch=1800, 기울기=nan, 기울기2=nan 절편=nan
# epoch=1900, 기울기=nan, 기울기2=nan 절편=nan
# epoch=2000, 기울기=nan, 기울기2=nan 절편=nan
